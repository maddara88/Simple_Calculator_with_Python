# %%
class cal:
    def add(self):
        print(f"x + y = {x+y}")
    def sub(self):
        print(f"x - y = {x-y}")
    def div(self):
        print(f"x / y = {x/y}")
    def mul(self):
        print(f"x * y = {x*y}")
        
x= int(input("please input your first number: "))
print(" ")
y = int(input("please input your second number"))
obj =cal()
print(" ")
choice = 1
while choice >0:
    print("1. for Add")
    print("2. for Subtract")
    print("3. for Divide")
    print("4. for Multiply")
    print("0. for  Exit")
    print(" ")
    choice = int(input("please enter your option"))
    if choice == 1:
        obj.add()
    elif choice == 2:
        obj.sub()
    elif choice == 3:
        obj.div()
    elif choice == 4:
        obj.mul()
    elif choice == 0:
        print("bye bye")
    else:
        print("please enter a valid response")
# Out:
# please input your first number: 8
#
# please input your second number12
#
# 1. for Add
# 2. for Subtract
# 3. for Divide
# 4. for Multiply
# 0. for  Exit
#
# please enter your option1
# x + y = 20
# 1. for Add
# 2. for Subtract
# 3. for Divide
# 4. for Multiply
# 0. for  Exit
#
# please enter your option2
# x - y = -4
# 1. for Add
# 2. for Subtract
# 3. for Divide
# 4. for Multiply
# 0. for  Exit
#
# please enter your option3
# x / y = 0.6666666666666666
# 1. for Add
# 2. for Subtract
# 3. for Divide
# 4. for Multiply
# 0. for  Exit
#
# please enter your option4
# x * y = 96
# 1. for Add
# 2. for Subtract
# 3. for Divide
# 4. for Multiply
# 0. for  Exit
#
# please enter your option5
# please enter a valid response
# 1. for Add
# 2. for Subtract
# 3. for Divide
# 4. for Multiply
# 0. for  Exit
#
# please enter your option6
# please enter a valid response
# 1. for Add
# 2. for Subtract
# 3. for Divide
# 4. for Multiply
# 0. for  Exit
#
# please enter your option0
# bye bye
